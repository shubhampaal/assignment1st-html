# %% [markdown]
# #Assignment Code: FSD-AG-001

# %% [markdown]
# Question 1 : Explain the basic structure of an HTML page. Why is it important to follow
# this structure?
#
#     answer= this is sytanx of html langauage , and a proper structure make our web page  clean  , and its easy for search engines  and web reading technology to understand web page and its also give
#     good user experiance
#
#     #html structure
#
#       <!DOCTYPE html>
#       <html lang="en">
#       <head>
#          <meta charset="UTF-8">
#          <meta name="viewport" content="width=device-width, initial-scale=1.0">
#          <title>First</title>
#       </head>
# `       <body>
#           <h1>Hello World</h1>
#           <p>Welocome</p>
#         </body>
#       </html>

# %% [markdown]
# Question 2: You’re building a small personal profile page. Which HTML tags will you
# use to highlight your name as a heading, describe yourself in a paragraph, and
# emphasize a key skill?
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>First</title>
# </head>
# <body>
# <h1>Shubham pal</h1>
# <p>
# My name is Shubham Pal, and I am from Dehradun. I have recently completed my B.Tech in Computer Science. Currently, I have joined PW Skills to learn Full Stack Development.
# I am a <em>quick learner</em>  who enjoys <em> solving problems</em> and working effectively in team environments. My soft skills include quick learning ability and good <em>communication skills</em> communication skills. My technical skills include<em >HTML, CSS, JavaScript, and Python.</em>
# Additionally, I have six months of experience working as an IT Executive at Blinkit, where I was part of the PaaS (Printing as a Service) team.
# </p>
# </body>
# </html>

# %% [markdown]
# Question 3: Look at the code below. Can you find and fix the mistake?
# <!-- This is an HTML comment
# <h1>Welcome to my website</h1>
#
#
#
# ->answer
#
# <!-- This is an HTML comment-->
# <h1>Welcome to my website</h1>

# %% [markdown]
# Question 4: You’re creating a form that asks the user to enter their name, select their
# country from a list, and click a button to submit. Write the HTML code for this.
#
#     answer=
#       <!DOCTYPE html>
#       <html lang="en">
#       <head>
#           <meta charset="UTF-8">
#           <meta name="viewport" content="width=device-width, initial-scale=1.0">
#           <title>form</title>
#       </head>
#       <body>
#           <div >
#               <h1>Resistration From</h1>
#               <form >
#                   <label for="name">Name</label>
#                   <input type="text" name="name" placeholder="Name" ><br><br>
#                   <label for="country">Choose your country</label>
#                   <select name="country" id="cars">
#                       <option value="india">india</option>
#                       <option value="pakistan">pakistan</option>
#                       <option value="china">china</option>
#                       <option value="usa">USA</option>
#                   </select><br><br>
#                   <input type="submit" name="submit">
#               </form>
#           </div>
#
#       </body>
#       </html>

# %% [markdown]
# Question 5: Write short HTML code to show your favorite fruits in a bulleted list and
# your top 3 programming languages in a numbered list.
#
#     answer=
#
#     <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <div>
#         <h2>My favorite fruits </h2>
#         <ul>
#             <li>applle</li>
#             <li>grapes</li>
#             <li>mango</li>
#             <li>watermelon</li>
#         </ul>
#         <h2>My favorite programing language  </h2>
#         <ol type="1">
#             <li>python </li>
#             <li>java</li>
#             <li>php</li>
#         </ol>
#
#
#     </div>
# </body>
# </html>

# %% [markdown]
# Question 6: Ravi wants to leave a note in his HTML file so that only other developers
# can see it, not the users on the website. How should he do this? Why are such notes
# useful?
#
#     answer=
#     Helps developers understand what different parts of the code do,
#     Useful when multiple developers are working on the same project,
#     Makes it easier to maintain or update the code later,
#
#
#     #code
#
#     <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <!--this is my favourate fruits list-->
#     <div>
#         <h2>My favorite fruits </h2>
#         <ul>
#             <li>applle</li>
#             <li>grapes</li>
#             <li>mango</li>
#             <li>watermelon</li>
#         </ul>
#     <!--this is my favourate language  list-->
#         <h2>My favorite programing language  </h2>
#         <ol type="1">
#             <li>python </li>
#             <li>java</li>
#             <li>php</li>
#         </ol>
#
#
#     </div>
# </body>
# </html>

# %% [markdown]
# Question 7: Here’s a form snippet. Can you spot the error and rewrite the correct
# version?
#
#     answer=
#       In this button tag  seplling is wrong and and input tag is self closing tag
#
#
#       #code
#
#       <!DOCTYPE html>
#       <html lang="en">
#       <head>
#           <meta charset="UTF-8">
#           <meta name="viewport" content="width=device-width, initial-scale=1.0">
#           <title>Document</title>
#       </head>
#       <body>
#
#       <form>
#       <input name="email"/>
#       <select>
#         <option>India</option>
#       </select>
#       <button>Send</button>
#       </form>
#       </body>
#       </html>
